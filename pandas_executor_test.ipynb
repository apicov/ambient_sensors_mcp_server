# %%
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
df = pd.DataFrame({
    'A': [1, 2, 3], 
    'B': [4, 5, 6]
})
query_cache = {"1":df}

# %%
from python_executor import PandasExecutor

# %%
pandas = PandasExecutor()

# %%
code = "print(df.head())"
output = pandas.execute_code("1",query_cache, code)
print(output)
# Out:
# Executing script:
#
# import pickle
# import pandas as pd
# import traceback
#
# # Load DataFrame
# with open('/data/dataframe.pkl', 'rb') as f:
#     df = pickle.load(f)
#
# print("DataFrame loaded:", df.shape[0], "rows,", df.shape[1], "columns")
#
# try:
#      print(df.head())
# except Exception as e:
#     print("Error:", str(e))
#     traceback.print_exc()
#
# -------------------------------------
# DataFrame loaded: 3 rows, 2 columns
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
